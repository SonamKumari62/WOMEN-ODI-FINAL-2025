# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ODI_DATASETS.csv')
df
# Out:
#     Position             Player       Country  Matches  Innings  Notouts  \
# 0          1    Laura Wolvaardt  South Africa        9        9        1
# 1          2    Smriti Mandhana         India        9        9        1
# 2          3   Ashleigh Gardner     Australia        7        5        1
# 3          4      Pratika Rawal         India        7        6        0
# 4          5  Phoebe Litchfield     Australia        7        7        1
# 5          6       Alyssa Healy     Australia        5        5        1
# 6          7  Jemimah Rodrigues         India        8        7        2
# 7          8      Sophie Devine   New Zealand        7        5        0
# 8          9     Heather Knight       England        8        7        1
# 9         10   Nat Sciver-Brunt       England        8        6        0
# 10        11   Harmanpreet Kaur         India        9        8        0
# 11        12        Richa Ghosh         India        8        8        2
# ...

# %%
df.head()
# Out:
#    Position             Player       Country  Matches  Innings  Notouts  Runs  \
# 0         1    Laura Wolvaardt  South Africa        9        9        1   571
# 1         2    Smriti Mandhana         India        9        9        1   434
# 2         3   Ashleigh Gardner     Australia        7        5        1   328
# 3         4      Pratika Rawal         India        7        6        0   308
# 4         5  Phoebe Litchfield     Australia        7        7        1   304
#
#    Highest_score  Average  Balls_faced  Strike_rate  Hundreds  Fifties  Ducks  \
# 0            169    71.37          578        98.78         2        3      0
# 1            109    54.25          438        99.08         1        2      0
# 2            115    82.00          252       130.15         2        1      0
# 3            122    51.33          396        77.77         1        1      0
# 4            119    50.66          271       112.17         1        1      0
#
#    Fours  Sixes
# ...

# %%
df.columns
# Out:
# Index(['Position', 'Player', 'Country', 'Matches', 'Innings', 'Notouts',
#        'Runs', 'Highest_score', 'Average', 'Balls_faced', 'Strike_rate',
#        'Hundreds', 'Fifties', 'Ducks', 'Fours', 'Sixes'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Position         0
# Player           0
# Country          0
# Matches          0
# Innings          0
# Notouts          0
# Runs             0
# Highest_score    0
# Average          0
# Balls_faced      0
# Strike_rate      0
# Hundreds         0
# Fifties          0
# Ducks            0
# Fours            0
# Sixes            0
# dtype: int64

# %%
df.groupby("Player")["Runs"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Player'>

# %%
plt.hist(df["Runs"])
# Out:
# (array([4., 4., 4., 1., 0., 0., 1., 0., 0., 1.]),
#  array([220. , 255.1, 290.2, 325.3, 360.4, 395.5, 430.6, 465.7, 500.8,
#         535.9, 571. ]),
#  <BarContainer object of 10 artists>)

# %%
df["bndry_runs"] = df["Fours"]*4 + df["Sixes"]*6
df
# Out:
#     Position             Player       Country  Matches  Innings  Notouts  \
# 0          1    Laura Wolvaardt  South Africa        9        9        1
# 1          2    Smriti Mandhana         India        9        9        1
# 2          3   Ashleigh Gardner     Australia        7        5        1
# 3          4      Pratika Rawal         India        7        6        0
# 4          5  Phoebe Litchfield     Australia        7        7        1
# 5          6       Alyssa Healy     Australia        5        5        1
# 6          7  Jemimah Rodrigues         India        8        7        2
# 7          8      Sophie Devine   New Zealand        7        5        0
# 8          9     Heather Knight       England        8        7        1
# 9         10   Nat Sciver-Brunt       England        8        6        0
# 10        11   Harmanpreet Kaur         India        9        8        0
# 11        12        Richa Ghosh         India        8        8        2
# ...

# %%
sns.scatterplot(x="Balls_faced", y="Runs",data=df)
plt.title("Runs vs Balls")
plt.show()

# %%
Runs=df.Runs
Runs
# Out:
# 0     571
# 1     434
# 2     328
# 3     308
# 4     304
# 5     299
# 6     292
# 7     289
# 8     288
# 9     262
# 10    260
# 11    235
# 12    235
# 13    227
# 14    220
# Name: Runs, dtype: int64

# %%
Player=df.Player
Player
# Out:
# 0       Laura Wolvaardt
# 1       Smriti Mandhana
# 2      Ashleigh Gardner
# 3         Pratika Rawal
# 4     Phoebe Litchfield
# 5          Alyssa Healy
# 6     Jemimah Rodrigues
# 7         Sophie Devine
# 8        Heather Knight
# 9      Nat Sciver-Brunt
# 10     Harmanpreet Kaur
# 11          Richa Ghosh
# 12         Tazmin Brits
# 13      Brooke Halliday
# 14            Amy Jones
# Name: Player, dtype: str

# %%
colors=["red","green","yellow","blue"]
colors
# Out:
# ['red', 'green', 'yellow', 'blue']

# %%
plt.figure(figsize=(6,6))
plt.pie(
    Runs,
    labels=Player,
    colors=colors,
    autopct='%1.1f%%',
    shadow=True,
    startangle=90

)
plt.title("women odi final - run contribution")
plt.show()
